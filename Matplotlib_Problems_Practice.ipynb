# %%
# !pip3 install pandas

# %%
# !pip3 install numpy
# !pip3 install sqlite3
# !pip3 install matplotlib.pyplot
# !pip3 install seaborn
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# ...

# %%
# !pip3 install matplotlib plotly seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
# import plotly as px

x= [1,2,3,4]
y= [10,20,30,40]

plt.plot(x,y)

plt.title("Sales Growth")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.grid(True , alpha=0.4)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# import plotly as px

x= [1,2,3,4]
y= [10,20,30,40]

plt.plot(x,y,color="purple" , linestyle = "--" ,marker = "o")

plt.title("Sales Growth")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.grid(True , alpha=0.4)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

Subjects = ["Math","Science","English","History","Physics"]
Marks = [85,90,78,88,92]

plt.plot(Subjects, Marks, marker = "o", color="green")

plt.title("Student Performance")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.grid(True , alpha=0.3)

plt.show()

# %% [markdown]
# LINE PLOT

# %%
import pandas as pd
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
sales  = [200, 220, 250, 280, 300, 330]

plt.plot(months,sales , color= "purple", linestyle = "--", marker="o")

plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.grid(True, alpha = 0.3)


plt.show()

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
product_A = [200, 220, 250, 280, 300, 330]
product_B = [150, 180, 160, 210, 240, 260]
product_C = [100, 120, 140, 130, 160, 190]

plt.plot(months , product_A , color= "orange" , marker = "o", linestyle="--", label="Product A")
plt.plot(months , product_B , color= "black" , marker = "o", linestyle="-", label="Product B")
plt.plot(months , product_C , color= "green" , marker = "o", linestyle=":", label="Product C")

plt.title("Monthly Sales on Products")
plt.xlabel("Months", fontsize=12)
plt.ylabel("Sales",fontsize=12)
plt.legend()
plt.grid(True,alpha=0.3)

plt.show()

# %% [markdown]
# BAR CHART

# %%
departments = ["Tech", "HR", "Finance", "Marketing", "Operations"]
headcount   = [45, 20, 30, 15, 25]
colors      = ["steelblue", "coral", "seagreen", "orange", "purple"]


plt.bar(departments, headcount, color = colors , edgecolor = "black", linewidth = 0.6, width = 0.6)

plt.title("Department Headcount", fontweight=100)
plt.xlabel("Departments")
plt.ylabel("Number of Employees")
plt.grid(axis="y" , alpha=0.3)

plt.show()

# %%
# Horizontal Bar chart 

headcount   = [45, 20, 30, 15, 25]
colors      = ["steelblue", "coral", "seagreen", "orange", "purple"]


plt.barh(departments, headcount, color = colors , edgecolor = "black", linewidth = 0.6)

plt.title("Department Headcount", fontweight=100)
plt.xlabel("Departments")
plt.ylabel("Number of Employees")
plt.grid(axis="y" , alpha=0.3)

plt.show()

# %% [markdown]
# HISTOGRAM CHARTS

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df

plt.hist(df["Age"], bins=30,color="orange", edgecolor="black")

plt.title("Age distribution of titanic Passengers", fontsize = 13)
plt.xlabel("Age")
plt.ylabel("No. Passengers")
plt.grid(axis = "y",alpha=0.3)

plt.show()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# SCATTER_PLOTS

# %%
# colors = df["Survived"].map({0:"red", 1:"green"})

plt.scatter(df['Age'], df['Fare'], c="orange", edgecolor="black", linewidth=0.4,alpha=0.3)

plt.title("Age vs Fare", fontweight="bold")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.grid(True, alpha=0.3)

plt.show()

# %%
filter_age = df.groupby("Age")["Fare"].mean()

filter2 = df.loc[df["Age"] == 80 , ["Age","Fare"]]

filter_age
filter2
# Out:
#       Age  Fare
# 630  80.0  30.0

# %%
# With color coding in scatter plots 

colors = df["Survived"].map({0:"maroon", 1:"seagreen"})

plt.scatter(df['Age'], df['Fare'], c=colors, edgecolor="black", linewidth=0.4)

# Manual legend
import matplotlib.patches as mpatches
legend_elements = [
    mpatches.Patch(color="maroon",     label="Age"),
    mpatches.Patch(color="seagreen",   label="Fare")
]

plt.legend(handles=legend_elements, fontsize=11)

plt.title("Age vs Fare", fontweight="bold")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# PIE_CHART

# %%
filter_survive = df["Pclass"].value_counts()
labels = ["Third Class", "First Class","Second Class"]
colors = ["maroon", "seagreen","orange"]
explode = (0.01, 0.02, 0.03)

plt.pie(filter_survive , labels = labels, colors = colors , explode=explode)

plt.title("Survival rate on Titanic", fontweight="bold")
plt.show()

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[["Pclass"]].value_counts()
# Out:
# Pclass
# 3         491
# 1         216
# 2         184
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 10))
plt.suptitle("Titanic Data Analysis Dashboard",
             fontsize=18, fontweight="bold")

# Chart 1 — top left
plt.subplot(2, 2, 1)                # (rows, cols, position)
plt.hist(df["Age"].dropna(), bins=30,
         color="steelblue", edgecolor="black", alpha=0.7)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.grid(alpha=0.3)

# Chart 2 — top right
plt.subplot(2, 2, 2)
survived = df["Survived"].value_counts()
plt.bar(["Did not survive", "Survived"],
        survived.values,
        color=["coral", "steelblue"],
        edgecolor="black")
plt.title("Survival Count")
plt.ylabel("Count")
plt.grid(axis="y", alpha=0.3)

# Chart 3 — bottom left
plt.subplot(2, 2, 3)
pclass_counts = df["Pclass"].value_counts().sort_index()
plt.bar(["Class 1", "Class 2", "Class 3"],
        pclass_counts.values,
        color=["gold", "silver", "brown"],
        edgecolor="black")
plt.title("Passengers per Class")
plt.ylabel("Count")
plt.grid(axis="y", alpha=0.3)

# Chart 4 — bottom right
plt.subplot(2, 2, 4)
plt.scatter(df["Age"], df["Fare"],
            alpha=0.4, color="steelblue",
            edgecolor="black", linewidth=0.3)
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # CLAUDE QUESTIONS PRACTICE FOR VISUALISATION

# %% [markdown]
# ## 📝 Practice Tasks — Matplotlib Only
#
# Use the Titanic dataset for all tasks:
# ```
# 1. Line plot — show passenger count
#    per Pclass as a trend line
#    (x = class, y = count)
#
# 2. Bar chart — passenger count
#    per Pclass with value labels on top
#
# 3. Horizontal bar chart —
#    average Fare per Pclass
#
# 4. Histogram — Fare distribution
#    (bins=50, notice the outliers!)
#
# 5. Scatter plot — Age vs Fare
#
# 6. Pie chart — Male vs Female
#    passenger split
#
# 7. Multiple lines —
#    Plot survival count AND
#    non-survival count per Pclass
#    on same chart (2 lines)
#
# 8. Build a 2x2 dashboard:
#    - Top left: Age histogram
#    - Top right: Survival bar chart
#    - Bottom left: Pclass bar chart
#    - Bottom right: Age vs Fare scatter
#    Add main title: "Titanic Analysis"

# %%
# ## 📝 Practice Tasks — Matplotlib Only

# Use the Titanic dataset for all tasks:
# ```
# 1. Line plot — show passenger count 
#    per Pclass as a trend line
#    (x = class, y = count)
pclass = df["Pclass"].value_counts().sort_index()
# print(pclass)
plt.figure(figsize=(10,6))

plt.plot(pclass.index , pclass.values , color="orange", linestyle="--",marker="o")
plt.title("Passenger Count Analysis" ,fontsize = 14, fontweight="bold")
plt.xlabel("Pclass", fontsize = 12)
plt.ylabel("Count of Passengers",fontsize = 12)
plt.grid(True, alpha =0.4)
plt.xticks([1, 2, 3],
           ["Class 1", "Class 2", "Class 3"])

plt.tight_layout()
plt.show()



# 📊 INSIGHT 1: Class 3 has most passengers (491) —
#               more than Class 1 and 2 combined
# 📊 INSIGHT 2: Class 2 has fewest passengers (184) —
#               middle class was least represented
# 📊 INSIGHT 3: Sharp rise from Class 2 to Class 3
#               shows Titanic was primarily a ship
#               for working class passengers

# %%
# 2. Bar chart — passenger count 
#    per Pclass with value labels on top
pclass = df["Pclass"].value_counts().sort_index()
colors_3 = ["orange", "maroon", "seagreen"]
labels_values = ["Class-1","Class-2", "Class-3"]

plt.figure(figsize=(10,6))

for x,y, c , labels in zip(pclass.index , pclass.values, colors_3, labels_values):
    plt.bar(x,y, color = c , edgecolor='black' ,label=labels)

plt.title("Passenger Count Analysis" ,fontsize = 14, fontweight="bold")
plt.xlabel("Pclass", fontsize = 12)
plt.ylabel("Count of Passengers",fontsize = 12)
plt.grid(True, alpha =0.4)
plt.xticks([1, 2, 3],
           ["Class 1", "Class 2", "Class 3"])

plt.tight_layout()
plt.legend()

plt.show()


# 📊 INSIGHT 1: Class 3 has most passengers (491) —
#               more than Class 1 and 2 combined
# 📊 INSIGHT 2: Class 2 has fewest passengers (184) —
#               middle class was least represented
# 📊 INSIGHT 3: Sharp rise from Class 2 to Class 3
#               shows Titanic was primarily a ship
#               for working class passengers

# %%
# 3. Horizontal bar chart — 
#    average Fare per Pclass
pclass = df["Pclass"].value_counts().sort_index()
colors_3 = ["orange", "maroon", "seagreen"]
labels_values = ["Class-1","Class-2", "Class-3"]

plt.figure(figsize=(10,6))

for x,y, c , labels in zip(pclass.index , pclass.values, colors_3, labels_values):
    plt.barh(x,y, color = c , edgecolor='black' ,label=labels)

plt.title("Passenger Count Analysis" ,fontsize = 14, fontweight="bold")
plt.xlabel("Count of Passengers", fontsize = 12)
plt.ylabel("Pclass",fontsize = 12)
plt.grid(axis="x", alpha =0.4)
plt.yticks([1, 2, 3],
           ["Class 1", "Class 2", "Class 3"])

plt.tight_layout()
plt.legend()

plt.show()

# %%
# 4. Histogram — Fare distribution
#    (bins=50, notice the outliers!)
fare_dist = df["Fare"]

plt.hist(fare_dist , bins=50, edgecolor = 'black' ,color="maroon")

plt.title("Fare Distribution",fontsize=14 , fontweight='bold')
plt.xlabel("Fare",fontsize=12)
plt.ylabel("Range(Frequency)",fontsize=12)
plt.grid(True , alpha=0.4)

plt.show()

# Insight_1 -- There are half number of people around fare with almost 10
# Insight_2 -- I think they are third class people may be
# Insight_3 -- there is an outlier with 500 fare , this looks something different , i think they are very luxurious 
                # with high priorities , with more safety
# Insight_4 -- There are some 50 equal no of distribution people around fare of 50 - 60

# %%
# 5. Scatter plot — Age vs Fare

age = df["Age"]
fare = df["Fare"]
colors= ['maroon']

plt.scatter(age , fare ,color=colors,  edgecolor = 'black', alpha = 0.5 )

plt.title("Age vs Fare",fontsize=14 , fontweight='bold')
plt.xlabel("Age",fontsize=12)
plt.ylabel("Fare",fontsize=12)
plt.grid(True , alpha=0.4)
# Manual legend
# import matplotlib.patches as mpatches
# legend_elements = [
#     mpatches.Patch(color="maroon",     label="Age"),
#     mpatches.Patch(color="seagreen",   label="Fare")
# ]

# plt.legend(handles=legend_elements, )

plt.show()


# Insight_1 -- There are two outliers having fare 500 above and at the age of around 36,37,
                # I think they have high facilities like safety precautions (life boats), high luxurios cabins and rooms etc
# Insight_2 -- There are more middle aged people like adults and they took fare below 50 , i think they may have some workers also because they cant afford high price of the fares
# Insight_3 -- There are 10% of people below age 10 , which is more children in the ship
# Insight_4 -- there are aged person also above 60

# %%
# 6. Pie chart — Male vs Female 
#    passenger split
sex = df["Sex"].value_counts()
colors = ["orange", 'maroon']
labels = ["male", "female"]
explode = (0.01, 0.02)

plt.pie(sex ,colors = colors , labels=labels, autopct='%1.1f%%', explode=explode )

plt.title("Male vs Female Analysis",fontweight = 'bold')

print(sex)
plt.show()

# 📊 INSIGHT 1: 65% of passengers were MALE, only 35% female
#               Men outnumbered women almost 2:1 on the ship

# 📊 INSIGHT 2: Despite being fewer in number, females had
#               much higher survival rate than males
#               "Women and children first" policy was enforced
#               We saw this in our SQL analysis —
#               233 females survived vs only 109 males

# 📊 INSIGHT 3: This creates an important ML insight —
#               Sex will be one of the strongest features
#               for predicting survival in our model
#               Being female significantly increased
#               chances of survival regardless of class
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

marks = [50,55,60,65,70,75,80,85,90]

sns.histplot(marks, bins=5)

plt.title("Marks Distribution")
plt.grid(True,alpha=0.3)
plt.show()

# %%
# 7. Multiple lines — 
#    Plot survival count AND 
#    non-survival count per Pclass
#    on same chart (2 lines)

# Count survival and non-survival per class
data = df.groupby(['Pclass','Survived']).size().unstack()

# Plot lines
plt.plot(data.index, data[1], marker='o', label='Survived')
plt.plot(data.index, data[0], marker='o', label='Not Survived')

plt.title("Survival vs Non-Survival by Passenger Class", fontweight="bold")
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.xticks([1,2,3],
        ["Class-1","Class-2","Class-3"])

plt.legend()
plt.grid(alpha=0.3)

plt.show()

# 📊 INSIGHT 1: Most survived people in the first class , due to high priority of first class

# 📊 INSIGHT 2: Most people died in the third class, as usual of low priority of third class i think they fought themselves for their lives due to high members in the cabin finally they led to died

# 📊 INSIGHT 3: There are moderate of number of people died and alive in the second class

# 📊 INSIGHT 4: The final conclusion is there is correlation of high priority in first class, the chances of people alive also high , as usual to third class also

# %%
# 8. Build a 2x2 dashboard:
#    - Top left: Age histogram
#    - Top right: Survival bar chart
#    - Bottom left: Pclass bar chart
#    - Bottom right: Age vs Fare scatter
#    Add main title: "Titanic Analysis"
plt.suptitle("Titanic Analysis",fontsize =18, fontweight= "bold")
plt.figure(figsize=(14, 10))

# Age histogram distribution
plt.subplot(2,2,1)
plt.hist(df["Age"] , bins=50, color="orange", edgecolor='black')
plt.title("Age Analysis",fontsize=10 , fontweight='bold')
plt.xlabel("Age",fontsize=8)
plt.ylabel("Frequency",fontsize=8)
plt.grid(True , alpha=0.4)


# Survival Analysis
plt.subplot(2,2,2)
sur = df['Survived'].value_counts()
colors=["maroon", "seagreen"]
plt.bar(sur.index, sur.values ,color = colors,  edgecolor='black')
plt.title("Survival Analysis",fontsize=10 , fontweight='bold')
plt.xlabel("Survived",fontsize=8)
plt.ylabel("Count",fontsize=8)
plt.xticks([0,1],
        ["Not Survived", "Survived"])
plt.grid(True , alpha=0.4)


# Pclass Analysis
plt.subplot(2,2,3)
pclass = df['Pclass'].value_counts().sort_index()
colors=["orange", "blue", "red"]
plt.bar(pclass.index, pclass.values ,color = colors,  edgecolor='black')
plt.title("Pclass Analysis",fontsize=10 , fontweight='bold')
plt.xlabel("Pclass",fontsize=8)
plt.ylabel("Count",fontsize=8)
plt.xticks([1,2,3],
        ["First Class", "Second Class", "Third Class"])
plt.grid(True , alpha=0.4)


# 
plt.subplot(2,2,4)
age = df["Age"]
fare = df["Fare"]
colors_2= ['maroon']

plt.scatter(age , fare ,color=colors_2,  edgecolor = 'black', alpha = 0.5 )

plt.title("Age vs Fare",fontsize=10 , fontweight='bold')
plt.xlabel("Age",fontsize=8)
plt.ylabel("Fare",fontsize=8)
plt.grid(True , alpha=0.4)

plt.tight_layout()
plt.show()

# %%
df.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.pairplot(df)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # ChatGPT QUESTIONS FOR VISUALISATION

# %%
Days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
Visitors = [120 , 150 , 170 , 160, 200]
# colors_2 = ["orange", "purple"]

plt.figure(figsize=(10,6))

plt.plot(Days, Visitors , color = "orange" , linestyle="--", marker="o")
plt.title("Total Visiting scenario")
plt.xlabel("Days")
plt.ylabel("Visitors")
plt.grid(True , alpha = 0.4)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

marks = [45,50,52,60,65,70,72,75,80,85,90,92]

plt.hist(marks , edgecolor= "black", width=4)

plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt

hours = [1,2,3,4,5,6,7]
marks = [40,45,50,60,65,70,80]

plt.scatter(hours, marks,
            color="purple",
            s=100,
            alpha=0.7)

plt.title("Study Hours vs Marks")
plt.xlabel("Hours Studied")
plt.ylabel("Marks")

plt.grid(alpha=0.3)

plt.show()

# %%
advertising_budget = [10,20,30,40,50,60]
sales = [100,150,200,240,300,360]

# plt.figure(figsize=(10,6))

plt.scatter(advertising_budget , sales , color="orange", edgecolor="black", s=50)

plt.title("Advertising vs Sales")
plt.xlabel("Advertising Budget")
plt.ylabel("Sales")
plt.grid(True,alpha=0.4)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

fig, ax = plt.subplots(1,2)

marks = [45,50,52,60,65,70,72,75,80,85,90,92]

ax[0].hist(marks)
ax[0].set_title("Marks Distribution")

hours = [1,2,3,4,5,6,7]
scores = [40,45,50,60,65,70,80]

ax[1].scatter(hours, scores)
ax[1].set_title("Study vs Score")

plt.show()

# %%
marks = [50,55,60,65,70,75,80,85,90]
hours = [1,2,3,4,5,6,7,8,9]
scores = [40,45,50,55,60,65,70,75,80]

plt.figure(figsize=(19,10))

plt.suptitle("Multiple Charts in one Canvas",fontsize = 20 , fontweight="bold")

# Histogram of Marks distribution
plt.subplot(1,2,1)

plt.hist(marks, color="orange",edgecolor = 'black')
plt.title("Marks Distribution", fontsize=14,fontweight='black')
plt.xlabel("Marks", fontsize = 12)
plt.ylabel("Frequency(Range)",fontsize = 12)
plt.grid(True, alpha=0.4)


plt.subplot(1,2,2)

plt.scatter(hours, scores, color="orange",edgecolor = 'black')
plt.title("Score Analysis" , fontsize=14,fontweight='black')
plt.xlabel("Hours",fontsize=12)
plt.ylabel("Score", fontsize=12)
plt.grid(True, alpha=0.4)

plt.tight_layout()
plt.show()
